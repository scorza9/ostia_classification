# %%
# !pip install git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab
# !pip install git+https://github.com/AAMIASoftwares-research/DatasetUtilities.git@google-colab
# Out:
# Collecting git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab
#   Cloning https://github.com/AAMIASoftwares-research/HCATNetwork.git (to revision google-colab) to c:\users\zaira\appdata\local\temp\pip-req-build-cb5tkbcq
#   Resolved https://github.com/AAMIASoftwares-research/HCATNetwork.git to commit e94413cce5e4fad1a00a771112bf7e66e3501d4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (1.23.5)
# Requirement already satisfied: scipy in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (1.11.3)
# Requirement already satisfied: matplotlib in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (3.8.0)
# Requirement already satisfied: palettable in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (3.3.3)
# Requirement already satisfied: NetworkX in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (3.1)
# Requirement already satisfied: PyVis in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork==2023.11.14.post1) (0.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->hcatnetwork==2023.11.14.post1) (2.8.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork==2023.11.14.post1) (8.15.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork==2023.11.14.post1) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork==2023.11.14.post1) (3.0.2)
# Requirement already satisfied: backcall in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.2.0)
# Requirement already satisfied: decorator in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (5.7.1)
# Requirement already satisfied: exceptiongroup in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (1.0.4)
# Requirement already satisfied: colorama in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zaira\anaconda3\lib\site-packages (from jinja2>=2.9.6->PyVis->hcatnetwork==2023.11.14.post1) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\zaira\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->hcatnetwork==2023.11.14.post1) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\zaira\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\zaira\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.2.5)
# Requirement already satisfied: executing in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork==2023.11.14.post1) (0.2.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/AAMIASoftwares-research/HCATNetwork.git 'C:\Users\zaira\AppData\Local\Temp\pip-req-build-cb5tkbcq'
#   Running command git checkout -b google-colab --track origin/google-colab
#   branch 'google-colab' set up to track 'origin/google-colab'.
#   Switched to a new branch 'google-colab'
# Collecting git+https://github.com/AAMIASoftwares-research/DatasetUtilities.git@google-colab
#   Cloning https://github.com/AAMIASoftwares-research/DatasetUtilities.git (to revision google-colab) to c:\users\zaira\appdata\local\temp\pip-req-build-yjqvztis
#   Resolved https://github.com/AAMIASoftwares-research/DatasetUtilities.git to commit 9a1e327a6fc6b40b6191996c9bc01da4981de7c2
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab (from HearticDatasetManager==2023.11.30.post1)
#   Cloning https://github.com/AAMIASoftwares-research/HCATNetwork.git (to revision google-colab) to c:\users\zaira\appdata\local\temp\pip-install-vizljdeo\hcatnetwork_4ac959d3b3ba4c7387ad25a5c5136b13
#   Resolved https://github.com/AAMIASoftwares-research/HCATNetwork.git to commit e94413cce5e4fad1a00a771112bf7e66e3501d4d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\zaira\anaconda3\lib\site-packages (from HearticDatasetManager==2023.11.30.post1) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\zaira\anaconda3\lib\site-packages (from HearticDatasetManager==2023.11.30.post1) (3.8.0)
# Requirement already satisfied: scikit-learn in c:\users\zaira\anaconda3\lib\site-packages (from HearticDatasetManager==2023.11.30.post1) (1.3.2)
# Requirement already satisfied: vtk in c:\users\zaira\anaconda3\lib\site-packages (from HearticDatasetManager==2023.11.30.post1) (9.3.0)
# Requirement already satisfied: SimpleITK in c:\users\zaira\anaconda3\lib\site-packages (from HearticDatasetManager==2023.11.30.post1) (2.3.1)
# Requirement already satisfied: scipy in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (1.11.3)
# Requirement already satisfied: palettable in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (3.3.3)
# Requirement already satisfied: NetworkX in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (3.1)
# Requirement already satisfied: PyVis in c:\users\zaira\anaconda3\lib\site-packages (from hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zaira\anaconda3\lib\site-packages (from matplotlib->HearticDatasetManager==2023.11.30.post1) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\zaira\anaconda3\lib\site-packages (from scikit-learn->HearticDatasetManager==2023.11.30.post1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\zaira\anaconda3\lib\site-packages (from scikit-learn->HearticDatasetManager==2023.11.30.post1) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\zaira\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->HearticDatasetManager==2023.11.30.post1) (1.16.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (8.15.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\zaira\anaconda3\lib\site-packages (from PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (3.0.2)
# Requirement already satisfied: backcall in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.2.0)
# Requirement already satisfied: decorator in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (5.7.1)
# Requirement already satisfied: exceptiongroup in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (1.0.4)
# Requirement already satisfied: colorama in c:\users\zaira\anaconda3\lib\site-packages (from ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zaira\anaconda3\lib\site-packages (from jinja2>=2.9.6->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\zaira\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\zaira\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.2.5)
# Requirement already satisfied: executing in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\zaira\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->PyVis->hcatnetwork@ git+https://github.com/AAMIASoftwares-research/HCATNetwork.git@google-colab->HearticDatasetManager==2023.11.30.post1) (0.2.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/AAMIASoftwares-research/DatasetUtilities.git 'C:\Users\zaira\AppData\Local\Temp\pip-req-build-yjqvztis'
#   Running command git checkout -b google-colab --track origin/google-colab
#   branch 'google-colab' set up to track 'origin/google-colab'.
#   Switched to a new branch 'google-colab'
#   Running command git clone --filter=blob:none --quiet https://github.com/AAMIASoftwares-research/HCATNetwork.git 'C:\Users\zaira\AppData\Local\Temp\pip-install-vizljdeo\hcatnetwork_4ac959d3b3ba4c7387ad25a5c5136b13'
#   Running command git checkout -b google-colab --track origin/google-colab
#   branch 'google-colab' set up to track 'origin/google-colab'.
#   Switched to a new branch 'google-colab'

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
import hcatnetwork
import HearticDatasetManager
import numpy as np

# %%
# Set folder paths
ASOCA_FOLDER = "C:/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/heart_data/ASOCA/"
CAT08_FOLDER = "C:/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/heart_data/CAT08/"

# %%
# open image
image_file = os.path.join(
    ASOCA_FOLDER,
    HearticDatasetManager.asoca.DATASET_ASOCA_IMAGES_DICT["Normal"][1] 
)
image = HearticDatasetManager.asoca.AsocaImageCT(image_file)

# open graph and convert its coordinates to RAS right away
graph_file = os.path.join(
    ASOCA_FOLDER,
    HearticDatasetManager.asoca.DATASET_ASOCA_GRAPHS_RESAMPLED_05MM_DICT["Normal"][1]
)
graph = hcatnetwork.io.load_graph(
    graph_file,
    output_type=hcatnetwork.graph.SimpleCenterlineGraph
)
for node_id in graph.nodes:
    old_coords = np.array(
        [graph.nodes[node_id]["x"], graph.nodes[node_id]["y"], graph.nodes[node_id]["z"]]
    )
    new_coords = HearticDatasetManager.affine.apply_affine_3d(image.affine_centerlines2ras, old_coords)
    graph.nodes[node_id]["x"] = new_coords[0]   
    graph.nodes[node_id]["y"] = new_coords[1]
    graph.nodes[node_id]["z"] = new_coords[2]

# %%
# find min, max and avg radius in graph
minR = 10
maxR = 0
avgR = 0
for node_id in graph.nodes:
    r = graph.nodes[node_id]["r"]
    avgR += r
    if(r>maxR): maxR=r
    elif(r<minR): minR = r
        
avgR /= len(graph.nodes)

print(f'Min Radius: {minR}')
print(f'Max Radius: {maxR}')
print(f'Avg Radius: {avgR}')
# Out:
# Min Radius: 0.26122156230372007
# Max Radius: 2.251113897698272
# Avg Radius: 0.9808494702461318

# %%
# select Ostium coordinates and save radius
ids = graph.get_coronary_ostia_node_id()
coord_ostium_1 = np.array([graph.nodes[ids[0]]['x'],graph.nodes[ids[0]]['y'],graph.nodes[ids[0]]['z'],np.array([graph.nodes[ids[0]]['r']])])
coord_ostium_2 = np.array([graph.nodes[ids[1]]['x'],graph.nodes[ids[1]]['y'],graph.nodes[ids[1]]['z'],np.array([graph.nodes[ids[1]]['r']])])

# %%
# extract a cube from the original image
CUBE_SIDE_MM = 24
CUBE_ISOTROPIC_SPACING_MM = 0.5
CUBE_SIDE_N_SAMPLES = int(CUBE_SIDE_MM * (1/CUBE_ISOTROPIC_SPACING_MM))
NUM_CUBES_PATIENT = 100

# %%
# generates coordinate matrices from x,y,z sampled points. Flattening and trasposing is then performed to generate (Nx3) arrays
def get_cube_sample_points(center: np.ndarray, side_mm: float, n_samples_per_side: int):
    """Sample a cube centered in center with side side, n_samples points."""
    xs = np.linspace(center[0] - side_mm/2, center[0] + side_mm/2, n_samples_per_side)
    ys = np.linspace(center[1] - side_mm/2, center[1] + side_mm/2, n_samples_per_side)
    zs = np.linspace(center[2] - side_mm/2, center[2] + side_mm/2, n_samples_per_side)
    return np.array(np.meshgrid(xs, ys, zs)).reshape(3, -1).T

# returns samples as a (NxNxN) array
def cube_samples_to_array(samples: np.ndarray, n_samples_per_side: int) -> np.ndarray:
    """Convert samples from a cube to a numpy array."""
    return samples.reshape(n_samples_per_side, n_samples_per_side, n_samples_per_side)

# returns directly the cube as numpy (NxNxN) array from center point in RAS coordinates
def get_input_data_from_vertex_ras_position(
        image: HearticDatasetManager.cat08.Cat08ImageCT|HearticDatasetManager.asoca.AsocaImageCT,
        position: np.ndarray,
        side_mm: float,
        n_samples_per_side: int,
        affine=np.eye(4)
    ) -> np.ndarray:
    """Get the input data from a vertex position expressed in RAS coordinates system.

    Parameters
    ----------
    image : HearticDatasetManager.cat08.Cat08ImageCT | HearticDatasetManager.asoca.AsocaImageCT
        The image from which to extract the data.
    position : numpy.ndarray
        The position of the cube center in RAS coordinates system.
    side_mm : float
        The side of the cube in mm.
    n_samples_per_side : int
        The number of samples per side.
    affine : np.ndarray, optional
        The affine transformation to apply to the position of the samples used to create the cube, by default np.eye(4) (which does nothing).
        This is useful in data augmemtation, if you want to rotate, flip, or do whatever operation
        on the cube sample points, you can do it by passing the affine transformation here.
        For example, HearticDatasetManager.affine.get_affine_3d_rotation_around_vector() will rotate the cube (see the function docs).
    """
    # Get the cube sample points
    cube_pos = get_cube_sample_points(position, side_mm, n_samples_per_side)
    # Apply transformation affine if any
    if affine is None:
        affine = np.eye(4)
    cube_pos = HearticDatasetManager.affine.apply_affine_3d(affine, cube_pos)
    # Sample the image
    samples = image.sample(cube_pos, interpolation="linear").T
    # Convert to ndarray
    cube_array = cube_samples_to_array(samples, n_samples_per_side)
    return cube_array

# %%
# define lists to save patches and corresponding labels
cubes = []
labels = []

# firstly random sample along the graph
for cube_i in range(NUM_CUBES_PATIENT//2):
    # choose a random node of the graph
    node_id = np.random.choice(list(graph.nodes.keys()))
    # get the position of the node in RAS
    node_position = np.array([graph.nodes[node_id]["x"], graph.nodes[node_id]["y"], graph.nodes[node_id]["z"]])
    # select parameters for random translation
    r = np.random.uniform(0, avgR*1.5)#translation vector
    theta = np.random.uniform(0, 2*np.pi)#xy plane angle
    phi = np.random.uniform(0, np.pi)#z to xy plane angle
    # apply the translation to the selected point
    node_position += np.array([r*np.sin(phi)*np.cos(theta), r*np.sin(phi)*np.sin(theta), r*np.cos(phi)]).reshape(3,1)
    cube_array = get_input_data_from_vertex_ras_position(image,node_position,CUBE_SIDE_MM,CUBE_SIDE_N_SAMPLES)
    # compute distances from ostia to assign labels
    dist1 = np.sqrt(np.sum(np.square(coord_ostium_1[:3]-node_position)))
    dist2 = np.sqrt(np.sum(np.square(coord_ostium_2[:3]-node_position)))
    label = 1 if (dist1<=1.2*coord_ostium_1[-1] or dist2<=1.2*coord_ostium_2[-1]) else 0
    
    cubes.append(cube_array)
    labels.append(label)
    
cubes = np.array(cubes)
labels = np.array(labels)

# %%
# check dimensionality
print(f"Dim. cubes: {cubes.shape}")
print(f"Dim. labels: {labels.shape}")
# check the label distribution, expect none to very few class 1 samples 
print(f"Ostium labels: {np.sum(labels==1)}")
# Out:
# Dim. cubes: (50, 48, 48, 48)
# Dim. labels: (50,)
# Ostium labels: 1

# %%
# reconvert to list
cubes = list(cubes)
labels = list(labels)

# %%
# import random
# import tensorflow as tf
# from scipy import ndimage

# @tf.function
# def rotate(volume):
#     """Rotate the volume by a few degrees"""

#     def scipy_rotate(volume):
#         # define some rotation angles
#         angles = [-20, -10, -5, 5, 10, 20]
#         # pick angles at random
#         angle = random.choice(angles)
#         # rotate volume
#         volume = ndimage.rotate(volume, angle, reshape=False)
#         volume[volume < 0] = 0
#         volume[volume > 1] = 1
#         return volume

#     augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
#     return augmented_volume

# %%
# then sample locally from the ostia
angles = [-20, -10, -5, 5, 10, 20]
for cube_i in range(NUM_CUBES_PATIENT//2):
    # select one of the two ostia
    node_id = np.random.choice(ids)
    # get the position of the node in RAS
    node_position = np.array([graph.nodes[node_id]["x"], graph.nodes[node_id]["y"], graph.nodes[node_id]["z"]])
    # select parameters for random translation
    r = np.random.uniform(-graph.nodes[node_id]["r"]*1.2, graph.nodes[node_id]["r"]*1.2)#translation vector
    theta = np.random.uniform(0, 2*np.pi)#xy plane angle
    phi = np.random.uniform(0, np.pi)#z to xy plane angle
    # apply the translation to the selected point
    node_position += np.array([r*np.sin(phi)*np.cos(theta), r*np.sin(phi)*np.sin(theta), r*np.cos(phi)]).reshape(3,1)
    cube_array = get_input_data_from_vertex_ras_position(image,node_position,CUBE_SIDE_MM,CUBE_SIDE_N_SAMPLES)
    # compute distances from ostia to assign labels
    dist1 = np.sqrt(np.sum(np.square(coord_ostium_1[:3]-node_position)))
    dist2 = np.sqrt(np.sum(np.square(coord_ostium_2[:3]-node_position)))
    label = 1 if (dist1<=1.2*coord_ostium_1[-1] or dist2<=1.2*coord_ostium_2[-1]) else 0
    
    # fare data augmentation qui
    
    #     # pick angles at random
    # angle = random.choice(angles)
    # cube_array = ndimage.rotate(cube_array, angle, reshape=False)
    # cubes[50+cube_i] = cube_array
    # labels[50+cube_i] = label


    cubes.append(cube_array)
    labels.append(label)
    
cubes = np.array(cubes)
labels = np.array(labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\zaira\Documents\uni\HIGH_PERFORMANCE_COMPUTING\Neuroengineering\project\Source\data-balancing.ipynb Cell 13 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a>     label = 1 if (dist1<=1.2*coord_ostium_1[-1] or dist2<=1.2*coord_ostium_2[-1]) else 0
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a>     # fare data augmentation qui
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a>     #     # pick angles at random
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=24'>25</a>     # cubes[50+cube_i] = cube_array
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=25'>26</a>     # labels[50+cube_i] = label
# ---> <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=28'>29</a>     cubes.append(cube_array)
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=29'>30</a>     labels.append(label)
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X14sZmlsZQ%3D%3D?line=31'>32</a> cubes = np.array(cubes)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
print(cube_array.shape)
# Out:
# (48, 48, 48)

# %%
print(cubes)
# Out:
# [[[[-7.38248561e+02 -7.59757618e+02 -7.62933711e+02 ... -8.00745934e+02
#     -7.96060438e+02 -7.82963149e+02]
#    [-7.44231631e+02 -7.36529881e+02 -7.52407210e+02 ... -7.60086955e+02
#     -7.71101335e+02 -7.71013979e+02]
#    [-7.28036490e+02 -7.16850082e+02 -7.33161587e+02 ... -6.84009060e+02
#     -7.31736416e+02 -7.66083852e+02]
#    ...
#    [ 4.39710181e+02  4.40436656e+02  4.29032846e+02 ...  1.42917256e+02
#      1.93841986e+02  2.24274822e+02]
#    [ 4.20977289e+02  4.33190275e+02  4.18076658e+02 ...  1.14575409e+02
#      1.50995804e+02  1.98317312e+02]
#    [ 4.04137505e+02  4.18529925e+02  4.14404775e+02 ...  8.21235410e+01
#      1.23064829e+02  1.90227271e+02]]
#
#   [[-7.53738424e+02 -7.67317612e+02 -7.53235300e+02 ... -7.88742254e+02
#     -8.14284427e+02 -8.09570661e+02]
#    [-7.41210966e+02 -7.43099356e+02 -7.55274194e+02 ... -7.94853720e+02
#     -8.16958532e+02 -7.97411541e+02]
#    [-6.57986387e+02 -6.65548201e+02 -7.02056816e+02 ... -7.73784566e+02
#     -8.01694281e+02 -7.85050085e+02]
#    ...
#    [ 4.13203100e+02  4.20904695e+02  4.29284443e+02 ...  9.65039405e+01
#      1.59290081e+02  1.82177418e+02]
#    [ 4.11415371e+02  4.29965466e+02  4.34423412e+02 ...  7.14056869e+01
#      1.30971440e+02  1.55205908e+02]
#    [ 4.03702041e+02  4.20962083e+02  4.30822455e+02 ...  2.07150193e+01
#      8.23713583e+01  1.38203867e+02]]
#
#   [[-7.40889453e+02 -7.47762885e+02 -7.25611719e+02 ... -7.84377681e+02
#      4.45723291e+01  2.42874837e+01]
#    ...
#    [-1.40070417e+02 -1.44333999e+02 -1.22072330e+02 ... -8.99826620e+02
#     -8.89337231e+02 -8.86455295e+02]
#    [-1.47007151e+02 -1.22488115e+02 -9.90801381e+01 ... -9.28984878e+02
#     -8.83372867e+02 -8.39663479e+02]
#    [-1.29602149e+02 -8.15342562e+01 -7.32069622e+01 ... -9.02739825e+02
#     -8.68470108e+02 -8.29126770e+02]]]
#
#
#  ...
#
#
#  [[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  [[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 1.76710129e+02  1.70786105e+02  1.51345587e+02 ...  4.95918280e+02
#      5.21481802e+02  5.36502496e+02]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 1.93291928e+02  1.69334585e+02  1.78883362e+02 ...  5.46020320e+02
#      5.44685495e+02  5.56860409e+02]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 4.28669893e+02  4.27671198e+02  4.54206169e+02 ...  4.05823038e+02
#      3.31742535e+02  2.96612072e+02]
#    [ 4.46255981e+02  4.51485690e+02  4.76342103e+02 ...  4.86365427e+02
#      4.24746111e+02  3.76548652e+02]
#    [ 4.63941861e+02  4.74929431e+02  4.51845131e+02 ...  5.01273728e+02
#      4.74647354e+02  4.33993979e+02]
#    ...
#    [ 1.66083861e+02  1.57272852e+02  1.61094798e+02 ...  5.39055291e+02
#      5.14577214e+02  5.05227587e+02]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 1.64698875e+02  1.70855627e+02  1.50741759e+02 ...  2.02017862e+02
#      1.64837122e+02  1.82175822e+02]
#    ...
#    [ 2.42407456e+01  1.42528787e+01 -6.38457896e+00 ...  2.47649694e+02
#      2.68953893e+02  2.55084303e+02]
#    [ 2.20819072e+00 -4.73512139e+00 -1.75432434e+01 ...  2.53368430e+02
#      2.71287530e+02  2.35625024e+02]
#    [-1.45792947e+01 -3.47499942e+01 -5.86538308e+01 ...  2.25759922e+02
#      2.50289157e+02  2.16056222e+02]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 1.60611498e+02  1.75012792e+02  1.08668369e+02 ...  2.00957401e+02
#      1.83558351e+02  2.00886457e+02]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 1.81680415e+02  1.92611002e+02  1.15087628e+02 ...  2.10535826e+02
#      2.09381213e+02  2.29618274e+02]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  [[[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]]

# %%
# check dimensionality
print(f"Dim. cubes: {cubes.shape}")
print(f"Dim. labels: {labels.shape}")
# check label distribution, now expect even size
print(f"Ostium labels: {np.sum(labels==1)}")
# Out:
# Dim. cubes: (100, 48, 48, 48)
# Dim. labels: (100,)
# Ostium labels: 51

# %%
# plot label 0 cube
first_sample = cubes[74]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = first_sample.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %%
# plot label 1 cube
last_sample = cubes[98]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = last_sample.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %%
# original ostium 1
node_id = ids[0]
# get the position of the node in RAS
node_position = np.array([graph.nodes[node_id]["x"], graph.nodes[node_id]["y"], graph.nodes[node_id]["z"]])
cube_array_1 = get_input_data_from_vertex_ras_position(image,node_position,CUBE_SIDE_MM,CUBE_SIDE_N_SAMPLES)

# show it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = cube_array_1.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %%
# original ostium 1
node_id = ids[1]
# get the position of the node in RAS
node_position = np.array([graph.nodes[node_id]["x"], graph.nodes[node_id]["y"], graph.nodes[node_id]["z"]])
cube_array_2 = get_input_data_from_vertex_ras_position(image,node_position,CUBE_SIDE_MM,CUBE_SIDE_N_SAMPLES)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = cube_array_2.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %%
import skimage
cube_array_1_frangi = skimage.filters.frangi(cube_array_1)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = cube_array_1_frangi.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %%
cube_array_2_frangi = skimage.filters.frangi(cube_array_2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# Get the indices for each dimension
x, y, z = np.meshgrid(np.arange(48), np.arange(48), np.arange(48))

# Flatten the arrays for plotting
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = cube_array_2_frangi.flatten()

# Scatter plot
ax.scatter(x, y, z, c=values, cmap='gray')

# Show the plot
plt.show()

# %% [markdown]
# FIRST TRY WITH CNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
import numpy as np

import os

# %%
#load data
dataset = tf.data.Dataset.from_tensor_slices((cubes, labels))
print(dataset)
# for ele in dataset:
#     print(ele)

#shuffle the data
buffer_size = 1000
dataset = dataset.shuffle(buffer_size)
dataset.element_spec
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(48, 48, 48), dtype=tf.float64, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>
# (TensorSpec(shape=(48, 48, 48), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.int32, name=None))

# %%
#build train and validation sets
num_samples = len(cubes)
num_train_samples = int(0.8*num_samples)
num_val_samples = num_samples - num_train_samples

# Split the dataset into training and validation sets
train_dataset = dataset.take(num_train_samples).batch(batch_size)
val_dataset = dataset.skip(num_train_samples).batch(batch_size)

print("Number of samples in train and validation are %d and %d."
    % (num_train_samples, num_val_samples))

train_dataset.element_spec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\zaira\Documents\uni\HIGH_PERFORMANCE_COMPUTING\Neuroengineering\project\Source\data-balancing.ipynb Cell 24 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> num_val_samples = num_samples - num_train_samples
#       <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a> # Split the dataset into training and validation sets
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> train_dataset = dataset.take(num_train_samples).batch(batch_size)
#       <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a> val_dataset = dataset.skip(num_train_samples).batch(batch_size)
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> print("Number of samples in train and validation are %d and %d."
#      <a href='vscode-notebook-cell:/c%3A/Users/zaira/Documents/uni/HIGH_PERFORMANCE_COMPUTING/Neuroengineering/project/Source/data-balancing.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a>     % (num_train_samples, num_val_samples))
#
# NameError: name 'batch_size' is not defined

# %%
#data augmentation

# %%
#defining the model
def get_model(width=48, height=48, depth=48):
    """Build a 3D convolutional neural network model."""
    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=48, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=48, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=96, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=192, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=384, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="first_try")
    return model


# Build model.
model = get_model(width=48, height=48, depth=48)
model.summary()
# Out:
# Model: "first_try"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 48, 48, 48, 1)]   0
#
#  conv3d_30 (Conv3D)          (None, 46, 46, 46, 48)    1344
#
#  max_pooling3d_23 (MaxPoolin  (None, 23, 23, 23, 48)   0
#  g3D)
#
#  batch_normalization_30 (Bat  (None, 23, 23, 23, 48)   192
#  chNormalization)
#
#  conv3d_31 (Conv3D)          (None, 21, 21, 21, 48)    62256
#
#  max_pooling3d_24 (MaxPoolin  (None, 10, 10, 10, 48)   0
#  g3D)
#
#  batch_normalization_31 (Bat  (None, 10, 10, 10, 48)   192
#  chNormalization)
#
#  conv3d_32 (Conv3D)          (None, 8, 8, 8, 96)       124512
#
#  max_pooling3d_25 (MaxPoolin  (None, 4, 4, 4, 96)      0
#  g3D)
#
#  batch_normalization_32 (Bat  (None, 4, 4, 4, 96)      384
#  chNormalization)
#
#  conv3d_33 (Conv3D)          (None, 2, 2, 2, 192)      497856
#
#  max_pooling3d_26 (MaxPoolin  (None, 1, 1, 1, 192)     0
#  g3D)
#
#  batch_normalization_33 (Bat  (None, 1, 1, 1, 192)     768
#  chNormalization)
#
#  global_average_pooling3d_5   (None, 192)              0
#  (GlobalAveragePooling3D)
#
#  dense_13 (Dense)            (None, 384)               74112
#
#  dropout_9 (Dropout)         (None, 384)               0
#
#  dense_14 (Dense)            (None, 1)                 385
#
# =================================================================
# Total params: 762,001
# Trainable params: 761,233
# Non-trainable params: 768
# _________________________________________________________________

# %%
#example above, but with some dropout layers and regularization in convolutional layers
def get_model(width=48, height=48, depth=48):
    """Build a 3D convolutional neural network model."""
    size = depth
    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=48, kernel_size=3, activation="relu", kernel_regularizer=regularizers.l2(0.01))(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv3D(filters=48, kernel_size=3, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv3D(filters=96, kernel_size=3, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv3D(filters=192, kernel_size=3, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=384, activation="relu", kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.5)(x)  # Increased dropout for regularization

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="improved_first_model")
    return model

# Build the improved model.
model = get_model(width=48, height=48, depth=48)
model.summary()
# Out:
# Model: "improved_first_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 48, 48, 48, 1)]   0
#
#  conv3d_26 (Conv3D)          (None, 46, 46, 46, 48)    1344
#
#  max_pooling3d_19 (MaxPoolin  (None, 23, 23, 23, 48)   0
#  g3D)
#
#  batch_normalization_26 (Bat  (None, 23, 23, 23, 48)   192
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 23, 23, 23, 48)    0
#
#  conv3d_27 (Conv3D)          (None, 21, 21, 21, 48)    62256
#
#  max_pooling3d_20 (MaxPoolin  (None, 10, 10, 10, 48)   0
#  g3D)
#
#  batch_normalization_27 (Bat  (None, 10, 10, 10, 48)   192
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 10, 10, 10, 48)    0
#
#  conv3d_28 (Conv3D)          (None, 8, 8, 8, 96)       124512
#
#  max_pooling3d_21 (MaxPoolin  (None, 4, 4, 4, 96)      0
#  g3D)
#
#  batch_normalization_28 (Bat  (None, 4, 4, 4, 96)      384
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 4, 4, 4, 96)       0
#
#  conv3d_29 (Conv3D)          (None, 2, 2, 2, 192)      497856
#
#  max_pooling3d_22 (MaxPoolin  (None, 1, 1, 1, 192)     0
#  g3D)
#
#  batch_normalization_29 (Bat  (None, 1, 1, 1, 192)     768
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 1, 1, 1, 192)      0
#
#  global_average_pooling3d_4   (None, 192)              0
#  (GlobalAveragePooling3D)
#
#  dense_11 (Dense)            (None, 384)               74112
#
#  dropout_8 (Dropout)         (None, 384)               0
#
#  dense_12 (Dense)            (None, 1)                 385
#
# =================================================================
# Total params: 762,001
# Trainable params: 761,233
# Non-trainable params: 768
# _________________________________________________________________

# %%
# #defining the model
# #one huge max pooling layer at the end, with convolutional layers with batch normalization and activation in between
# def get_model(width=48, height=48, depth=48):
#     """Build a 3D convolutional neural network model."""
#     size = depth
#     inputs = keras.Input((width, height, depth, 1))

#     x = layers.Conv3D(filters=48, kernel_size=3, activation="relu")(inputs)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     x = layers.Conv3D(filters=48, kernel_size=3, activation="relu")(inputs)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     x = layers.Conv3D(filters=48, kernel_size=3, activation="relu")(inputs)
#     x = layers.BatchNormalization()(x)
#     x = layers.Activation("relu")(x)

#     x= layers.MaxPool3D(pool_size=2)(x)

#     outputs = layers.Dense(units=1, activation="sigmoid")(x)

#     # Define the model.
#     model = keras.Model(inputs, outputs, name="second_try")
#     return model


# # Build model.
# model = get_model(width=48, height=48, depth=48)
# model.summary()
# Out:
# Model: "second_try"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 48, 48, 48, 1)]   0
#
#  conv3d_25 (Conv3D)          (None, 46, 46, 46, 96)    2688
#
#  batch_normalization_25 (Bat  (None, 46, 46, 46, 96)   384
#  chNormalization)
#
#  activation_8 (Activation)   (None, 46, 46, 46, 96)    0
#
#  max_pooling3d_18 (MaxPoolin  (None, 23, 23, 23, 96)   0
#  g3D)
#
#  dense_10 (Dense)            (None, 23, 23, 23, 1)     97
#
# =================================================================
# Total params: 3,169
# Trainable params: 2,977
# Non-trainable params: 192
# _________________________________________________________________

# %%
#training
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
)

# Define callbacks.
# checkpoint_cb = keras.callbacks.ModelCheckpoint(
#     "3d_image_classification.h5", save_best_only=True
# )
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 100
model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[early_stopping_cb],
)
# Out:
# Epoch 1/100
# 3/3 - 2s - loss: 0.5530 - acc: 0.7375 - val_loss: 1.1744 - val_acc: 0.5500 - 2s/epoch - 651ms/step
# Epoch 2/100
# 3/3 - 1s - loss: 0.1052 - acc: 0.9750 - val_loss: 0.9516 - val_acc: 0.6000 - 1s/epoch - 365ms/step
# Epoch 3/100
# 3/3 - 1s - loss: 0.0318 - acc: 1.0000 - val_loss: 0.9828 - val_acc: 0.3500 - 1s/epoch - 373ms/step
# Epoch 4/100
# 3/3 - 1s - loss: 0.0149 - acc: 1.0000 - val_loss: 0.5482 - val_acc: 0.6500 - 1s/epoch - 350ms/step
# Epoch 5/100
# 3/3 - 1s - loss: 0.0134 - acc: 1.0000 - val_loss: 0.4241 - val_acc: 0.7000 - 1s/epoch - 352ms/step
# Epoch 6/100
# 3/3 - 1s - loss: 0.0115 - acc: 1.0000 - val_loss: 0.4640 - val_acc: 0.7500 - 1s/epoch - 359ms/step
# Epoch 7/100
# 3/3 - 1s - loss: 0.0074 - acc: 1.0000 - val_loss: 0.3936 - val_acc: 0.7500 - 1s/epoch - 365ms/step
# Epoch 8/100
# 3/3 - 1s - loss: 0.0070 - acc: 1.0000 - val_loss: 0.2818 - val_acc: 0.8500 - 1s/epoch - 380ms/step
# Epoch 9/100
# 3/3 - 1s - loss: 0.0070 - acc: 1.0000 - val_loss: 0.3195 - val_acc: 0.8500 - 1s/epoch - 384ms/step
# Epoch 10/100
# 3/3 - 1s - loss: 0.0133 - acc: 1.0000 - val_loss: 0.3242 - val_acc: 0.8000 - 1s/epoch - 373ms/step
# Epoch 11/100
# 3/3 - 1s - loss: 0.0071 - acc: 1.0000 - val_loss: 0.1490 - val_acc: 0.9500 - 1s/epoch - 357ms/step
# Epoch 12/100
# 3/3 - 1s - loss: 0.0087 - acc: 1.0000 - val_loss: 0.1999 - val_acc: 0.9000 - 1s/epoch - 367ms/step
# Epoch 13/100
# 3/3 - 1s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.1734 - val_acc: 0.9500 - 1s/epoch - 360ms/step
# Epoch 14/100
# 3/3 - 1s - loss: 0.0033 - acc: 1.0000 - val_loss: 0.1384 - val_acc: 1.0000 - 1s/epoch - 352ms/step
# Epoch 15/100
# 3/3 - 1s - loss: 0.0039 - acc: 1.0000 - val_loss: 0.1254 - val_acc: 0.9500 - 1s/epoch - 366ms/step
# Epoch 16/100
# 3/3 - 1s - loss: 0.0032 - acc: 1.0000 - val_loss: 0.0409 - val_acc: 1.0000 - 1s/epoch - 359ms/step
# Epoch 17/100
# 3/3 - 1s - loss: 0.0035 - acc: 1.0000 - val_loss: 0.1718 - val_acc: 1.0000 - 1s/epoch - 353ms/step
# Epoch 18/100
# 3/3 - 1s - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0663 - val_acc: 1.0000 - 1s/epoch - 355ms/step
# Epoch 19/100
# 3/3 - 1s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0842 - val_acc: 1.0000 - 1s/epoch - 351ms/step
# Epoch 20/100
# 3/3 - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.1029 - val_acc: 1.0000 - 1s/epoch - 352ms/step
# Epoch 21/100
# 3/3 - 1s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.1007 - val_acc: 1.0000 - 1s/epoch - 347ms/step
# Epoch 22/100
# 3/3 - 1s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.0977 - val_acc: 1.0000 - 1s/epoch - 359ms/step
# Epoch 23/100
# 3/3 - 1s - loss: 0.0054 - acc: 1.0000 - val_loss: 0.0758 - val_acc: 1.0000 - 1s/epoch - 354ms/step
# Epoch 24/100
# 3/3 - 1s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0970 - val_acc: 1.0000 - 1s/epoch - 355ms/step
# Epoch 25/100
# 3/3 - 1s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.0641 - val_acc: 1.0000 - 1s/epoch - 350ms/step
# Epoch 26/100
# 3/3 - 1s - loss: 0.0016 - acc: 1.0000 - val_loss: 0.0503 - val_acc: 1.0000 - 1s/epoch - 364ms/step
# Epoch 27/100
# 3/3 - 1s - loss: 0.0028 - acc: 1.0000 - val_loss: 0.0460 - val_acc: 1.0000 - 1s/epoch - 385ms/step
# Epoch 28/100
# 3/3 - 1s - loss: 0.0018 - acc: 1.0000 - val_loss: 0.0755 - val_acc: 1.0000 - 1s/epoch - 373ms/step
# Epoch 29/100
# 3/3 - 1s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0587 - val_acc: 1.0000 - 1s/epoch - 359ms/step

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
plt.title(model.name)
ax = ax.ravel()
for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])
